# %%
import pickle

# %%
load_model=pickle.load(open("simple_linear_regression_phase1_model.sav",'rb'))
result=load_model.predict([[13]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[148460.78806172]])

# %%
load_model=pickle.load(open("simple_linear_regression_phase1_model.sav",'rb'))
result=load_model.predict([[0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
